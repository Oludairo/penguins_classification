# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('penguins_lter.csv')
df
# Out:
#     studyName  Sample Number                              Species  Region  \
# 0     PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1     PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2     PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3     PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4     PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...            ...                                  ...     ...
# 339   PAL0910            120    Gentoo penguin (Pygoscelis papua)  Anvers
# 340   PAL0910            121    Gentoo penguin (Pygoscelis papua)  Anvers
# 341   PAL0910            122    Gentoo penguin (Pygoscelis papua)  Anvers
# 342   PAL0910            123    Gentoo penguin (Pygoscelis papua)  Anvers
# 343   PAL0910            124    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  Date Egg  \
# ...

# %%
df.shape
# Out:
# (344, 17)

# %%
df['Species'].unique()
# Out:
# array(['Adelie Penguin (Pygoscelis adeliae)',
#        'Chinstrap penguin (Pygoscelis antarctica)',
#        'Gentoo penguin (Pygoscelis papua)'], dtype=object)

# %% [markdown]
# ###### bar plot showing the different penguin species and the length of their culmen which is the dorsal ridge of a bird's bill.

# %%
fig = plt.figure(figsize=(11, 7))
sns.barplot(x='Species', y='Culmen Length (mm)', data = df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Culmen Length (mm)'>

# %% [markdown]
# ###### bar plot showing the different penguin species and the depth of culmen which is the dorsal ridge of a bird's bill.

# %%
fig = plt.figure(figsize=(11, 7))
sns.barplot(x='Species', y='Culmen Depth (mm)', data = df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Culmen Depth (mm)'>

# %% [markdown]
# ###### bar plot showing the different penguin species and the variations in their flipper lengths

# %%
fig = plt.figure(figsize=(11, 7))
sns.barplot(x='Species', y='Flipper Length (mm)', data = df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Flipper Length (mm)'>

# %% [markdown]
# ###### bar plot showing different penguin species and their body mass

# %%
fig = plt.figure(figsize=(11, 7))
sns.barplot(x='Species', y='Body Mass (g)', data = df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Body Mass (g)'>

# %% [markdown]
# ###### bar plot showing different penguin species and the numbers denoting the measure of the ratio of their stable isotopes 15N:14N

# %%
fig = plt.figure(figsize=(11, 7))
sns.barplot(x='Species', y='Delta 15 N (o/oo)', data = df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Delta 15 N (o/oo)'>

# %% [markdown]
# ###### bar plot showing the different penguin species and numbers denoting the measure of the ratio of their stable isotopes 13C:12C

# %%
fig = plt.figure(figsize=(11, 7))
sns.barplot(x='Species', y='Delta 13 C (o/oo)', data = df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Delta 13 C (o/oo)'>

# %% [markdown]
# ###### bar plot showing the concentration of the Adelie penguin specie in all three islands as opposed to the other species using numbers denoting the measure of the ratio of their stable isotopes 13C:12C

# %%
fig = plt.figure(figsize=(11, 7))
sns.barplot(x='Species', y='Delta 13 C (o/oo)', hue = 'Island', data = df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Delta 13 C (o/oo)'>

# %% [markdown]
# ######  bar plot showing the concentration of the Adelie penguin specie in all three islands as opposed to the other species using numbers denoting the measure of the ratio of their stable isotope 15N:14N

# %%
fig = plt.figure(figsize=(11, 7))
sns.barplot(x='Species', y='Delta 15 N (o/oo)', hue = 'Island', data = df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Delta 15 N (o/oo)'>

# %% [markdown]
# ###### bar plot showing the concentration of the Adelie Penguin in all three Islands as opposed to the two other species using the length of their culmen

# %%
fig = plt.figure(figsize=(11, 7))
sns.barplot(x='Species', y='Culmen Length (mm)', hue = 'Island', data = df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Culmen Length (mm)'>

# %% [markdown]
# ###### bar plot showing the concentration of the Adelie Penguin in all three Islands as opposed to the two other species using the depth of their culmen

# %%
fig = plt.figure(figsize=(11, 7))
sns.barplot(x='Species', y='Culmen Depth (mm)', hue = 'Island', data = df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Culmen Depth (mm)'>

# %% [markdown]
# ###### dropping the irrelevant columns

# %%
df = df.drop(['studyName','Sample Number','Individual ID','Stage','Comments','Region','Date Egg'], axis=1)

# %% [markdown]
# ###### using the ordinal encoder to convert objects to floats

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
encode = OrdinalEncoder()
df[['specie', 'island','clutch_completion','sex']] = encode.fit_transform(df[['Species', 'Island','Clutch Completion','Sex']])

# %% [markdown]
# ###### dropping the older columns

# %%
df_n = df.drop(columns=['Species', 'Island','Clutch Completion','Sex'])

# %%
df_n
# Out:
#      Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0                  39.1               18.7                181.0
# 1                  39.5               17.4                186.0
# 2                  40.3               18.0                195.0
# 3                   NaN                NaN                  NaN
# 4                  36.7               19.3                193.0
# ..                  ...                ...                  ...
# 339                 NaN                NaN                  NaN
# 340                46.8               14.3                215.0
# 341                50.4               15.7                222.0
# 342                45.2               14.8                212.0
# 343                49.9               16.1                213.0
#
#      Body Mass (g)  Delta 15 N (o/oo)  Delta 13 C (o/oo)  specie  island  \
# 0           3750.0                NaN                NaN     0.0     2.0
# ...

# %% [markdown]
# ###### checking for missing values

# %%
df_n.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Culmen Length (mm)   342 non-null    float64
#  1   Culmen Depth (mm)    342 non-null    float64
#  2   Flipper Length (mm)  342 non-null    float64
#  3   Body Mass (g)        342 non-null    float64
#  4   Delta 15 N (o/oo)    330 non-null    float64
#  5   Delta 13 C (o/oo)    331 non-null    float64
#  6   specie               344 non-null    float64
#  7   island               344 non-null    float64
#  8   clutch_completion    344 non-null    float64
#  9   sex                  334 non-null    float64
# dtypes: float64(10)
# memory usage: 27.0 KB

# %%
df_n.isna().sum()
# Out:
# Culmen Length (mm)      2
# Culmen Depth (mm)       2
# Flipper Length (mm)     2
# Body Mass (g)           2
# Delta 15 N (o/oo)      14
# Delta 13 C (o/oo)      13
# specie                  0
# island                  0
# clutch_completion       0
# sex                    10
# dtype: int64

# %% [markdown]
# ###### filling missing values with median values

# %%
df_ = df_n.fillna(df_n.median())

# %%
df_
# Out:
#      Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0                 39.10               18.7                181.0
# 1                 39.50               17.4                186.0
# 2                 40.30               18.0                195.0
# 3                 44.45               17.3                197.0
# 4                 36.70               19.3                193.0
# ..                  ...                ...                  ...
# 339               44.45               17.3                197.0
# 340               46.80               14.3                215.0
# 341               50.40               15.7                222.0
# 342               45.20               14.8                212.0
# 343               49.90               16.1                213.0
#
#      Body Mass (g)  Delta 15 N (o/oo)  Delta 13 C (o/oo)  specie  island  \
# 0           3750.0           8.652405          -25.83352     0.0     2.0
# ...

# %%
df_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Culmen Length (mm)   344 non-null    float64
#  1   Culmen Depth (mm)    344 non-null    float64
#  2   Flipper Length (mm)  344 non-null    float64
#  3   Body Mass (g)        344 non-null    float64
#  4   Delta 15 N (o/oo)    344 non-null    float64
#  5   Delta 13 C (o/oo)    344 non-null    float64
#  6   specie               344 non-null    float64
#  7   island               344 non-null    float64
#  8   clutch_completion    344 non-null    float64
#  9   sex                  344 non-null    float64
# dtypes: float64(10)
# memory usage: 27.0 KB

# %% [markdown]
# ###### for loop plotting box plots to check for outliers

# %%
for columns in ['Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)']:
    plt.figure(figsize=(8, 5))
    sns.boxplot(data = df_, x=columns)
    plt.title(columns)
    plt.show()

# %% [markdown]
# ######  heat map showing correlation between dependent and independent variables

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(df_.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###### splitting dataset into depedent and independent variables

# %%
X = df_.drop(['specie'], axis=1)
y = df_['specie']

# %% [markdown]
# ###### using the variance inflation factor to check for multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calcu_mult(df):
  vif = pd.DataFrame()
  vif["variables"] = X.columns
  vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

  return vif

# %%
calcu_mult(X)
# Out:
#              variables          VIF
# 0   Culmen Length (mm)   189.653197
# 1    Culmen Depth (mm)   210.379120
# 2  Flipper Length (mm)  1276.667031
# 3        Body Mass (g)   179.144285
# 4    Delta 15 N (o/oo)   445.254466
# 5    Delta 13 C (o/oo)   800.280368
# 6               island     3.280206
# 7    clutch_completion    10.016102
# 8                  sex    20.303600

# %%
y.value_counts()
# Out:
# 0.0    152
# 2.0    124
# 1.0     68
# Name: specie, dtype: int64

# %% [markdown]
# ###### Using smote to balance our categorical dependent variable in other to avoid bias in our model

# %%
from imblearn.over_sampling import SMOTE

# %%
sample = SMOTE()
X, y = sample.fit_resample(X, y)

# %%
y.value_counts()
# Out:
# 0.0    152
# 1.0    152
# 2.0    152
# Name: specie, dtype: int64

# %% [markdown]
# ###### normalizing dataset using the standard scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
normalizer = StandardScaler()
norm = pd.DataFrame(normalizer.fit_transform(X))

# %% [markdown]
# ###### splitting our normalized dataset into train and test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(norm, y, test_size=0.2, random_state=45)

# %% [markdown]
# ###### using the principal component analysis to check for important features

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components= 9)
model = pca.fit(norm)
PCA(n_components= 9)
# Out:
# PCA(n_components=9)

# %%
features = X.columns
importances = model.explained_variance_ratio_
indices = np.argsort(importances)[-9:]
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %% [markdown]
# ###### using the elbow method to determine the number of clusters in a data set

# %%
from sklearn.cluster import KMeans

# %%
lst = []
for ks in range(2, 20):
    km = KMeans(n_clusters = ks)
    kmeans = km.fit(X)
    lst.append(kmeans.inertia_)

fig = plt.figure(figsize= (15, 7))
plt.plot(range(2, 20), lst)
plt.grid(True)
plt.title("elbow_method")
# Out:
# Text(0.5, 1.0, 'elbow_method')

# %% [markdown]
# ###### from yellowbrick.cluster import SilhouetteVisualizer

# %%
fig, ax = plt.subplots(2, 2, figsize=(15,8))
for i in [2, 3, 4, 5]:
    km = KMeans(n_clusters=i, init='k-means++', n_init=10, max_iter=100, random_state=42)
    q, mod = divmod(i, 2)

    visualizer = SilhouetteVisualizer(km, colors='yellowbrick', ax=ax[q-1][mod])
    visualizer.fit(norm)

# %% [markdown]
# ###### fitting the training test into K-Neighbors Classifier model

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
neigh = KNeighborsClassifier(n_neighbors=5)
knn_model = neigh.fit(X_train, y_train)

# %% [markdown]
# ###### checking accuracy score

# %%
knn_model.score(X_train, y_train)
# Out:
# 0.9972527472527473

# %% [markdown]
# ###### predicting with the test

# %%
y_pred = knn_model.predict(X_test)

# %% [markdown]
# ###### using the confusion matrix to display the four quadrants that show the true and false positive and negative classes

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[28,  1,  0],
#        [ 0, 32,  0],
#        [ 0,  0, 31]])

# %% [markdown]
# #### From the confusion matrix above the model was able to classify 28 out of 29 for Adelie Penguin species, and 32 of Chinstrap penguin, 31 Gentoo penguin printing the precision,recall,and f1-score to determine how well the model has classified the dataset.

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.97      0.98        29
#          1.0       0.97      1.00      0.98        32
#          2.0       1.00      1.00      1.00        31
#
#     accuracy                           0.99        92
#    macro avg       0.99      0.99      0.99        92
# weighted avg       0.99      0.99      0.99        92

# %% [markdown]
# #### From the above classification report we can see that our model has 0.98 percent for classifying correctly the Adelie Penguin, 0.98 percent for classifying correctly the Chinstrap penguin, and then 100 percent for classifying correctly the Gentoo penguin with accuracy of 0.99.
# #### using the repeated k fold model to cross validate

# %%
from sklearn.model_selection import RepeatedKFold, cross_val_score

# %%
Cv_ = RepeatedKFold(n_splits=10, n_repeats=4, random_state=1)
score = cross_val_score(knn_model, X_test, y_test, scoring = "accuracy", cv = Cv_, n_jobs=1, error_score="raise")
np.mean(score)
# Out:
# 0.986111111111111

# %% [markdown]
# ####  The cross validation of our model shows that our model has 0.99 percentage of predicting correctly which is a good score given that our train and test score is the same
